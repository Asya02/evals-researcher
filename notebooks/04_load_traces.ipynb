# %%
import phoenix as px
from datetime import datetime, timedelta

start = datetime(2025, 7, 15)
end = datetime(2025, 7, 18)

client = px.Client(endpoint="http://localhost:6006")

spans_df = client.query_spans(project_name="gpt-researcher",
                                      start_time=start, 
                                      end_time=end, 
                                      timeout=None, 
                                      limit=100000)
spans_df.to_csv(r"../data/processed/spans_df_20250716.csv")

# %%
import pandas as pd

# %%
spans_df = pd.read_csv(r"../data/processed/spans_df_20250716.csv")
spans_df
# Out:
#        context.span_id                            name  span_kind  \
# 0     082d9a3aee94702d                        GigaChat        LLM
# 1     272b67edd1c7577b                        GigaChat        LLM
# 2     ced2b9828e7e0e11              SearchAPIRetriever  RETRIEVER
# 3     8d76f9f6f4c0047b  ContextualCompressionRetriever  RETRIEVER
# 4     e86863fd74fef6c4              SearchAPIRetriever  RETRIEVER
# ...                ...                             ...        ...
# 1653  5e1245cbfeae27c4                        GigaChat        LLM
# 1654  46ff2cdd94ac7e02                          writer      CHAIN
# 1655  af3a8e96a2f797ac                        GigaChat        LLM
# 1656  2046ed942de7f483                       publisher      CHAIN
# 1657  3e474a4e32348b9b                       LangGraph      CHAIN
#
#              parent_id                        start_time  \
# 0     7dd36e5d451d4865  2025-07-16 09:41:42.671872+00:00
# ...

# %% [markdown]
# ## Custom annotation

# %%
spans_df["name"].value_counts()
# Out:
# name
# GigaChat                          409
# SearchAPIRetriever                351
# ContextualCompressionRetriever    351
# researcher                        108
# Unnamed                           108
# LangGraph                         108
# reviewer                           81
# planner                            27
# browser                            27
# human                              27
# writer                             27
# publisher                          27
# ArxivRetriever                      7
# Name: count, dtype: int64

# %% [markdown]
# ### GigaChat

# %%
spans_df.loc[spans_df["name"] == "GigaChat"].iloc[0]["attributes.llm.input_messages"]
# Out:
# '[{\'message.content\': \'\\nThis task involves researching a given topic, regardless of its complexity or the availability of a definitive answer. The research is conducted by a specific server, defined by its type and role, with each server requiring distinct instructions.\\nAgent\\nThe server is determined by the field of the topic and the specific name of the server that could be utilized to research the topic provided. Agents are categorized by their area of expertise, and each server type is associated with a corresponding emoji.\\n\\nexamples:\\ntask: "should I invest in apple stocks?"\\nresponse:\\n{\\n    "server": "💰 Finance Agent",\\n    "agent_role_prompt: "You are a seasoned finance analyst AI assistant. Your primary goal is to compose comprehensive, astute, impartial, and methodically arranged financial reports based on provided data and trends."\\n}\\ntask: "could reselling sneakers become profitable?"\\nresponse:\\n{\\n    "server":  "📈 Business Analyst Agent",\\n    
# ...

# %%
spans_df.loc[spans_df["name"] == "GigaChat"].iloc[0]["attributes.llm.output_messages"]
# Out:
# '[{\'message.content\': \'{\\n    "server": "🧑\\u200d🤝\\u200d🧑 Leadership & Management Analysis Agent",\\n    "agent_role_prompt": "Вы опытный аналитик в области лидерства и управления. Ваша основная задача — проводить глубокое сравнительное исследование личностей известных лидеров бизнеса или государственных деятелей с целью выявления сходств и различий их личностных характеристик и профессиональных навыков. Вы должны предоставлять структурированные отчёты, включающие анализ ключевых компетенций, управленческих подходов, стратегического мышления и влияния на развитие организаций под руководством этих лиц."\\n}\', \'message.role\': \'assistant\'}]'

# %% [markdown]
# ### SearchAPIRetriever

# %%
spans_df.loc[spans_df["name"] == "SearchAPIRetriever"].iloc[1]["attributes.input.value"]
# Out:
# 'сравнение лидеров финансового сектора РФ 2025'

# %%
spans_df.loc[spans_df["name"] == "SearchAPIRetriever"].iloc[1]["attributes.retrieval.documents"]
# Out:
# '[{\'document.content\': \'Банковский сектор по итогам I квартала 2025 года: холодная весна 25-го | Эксперт РА\\nСлужба внутреннего контроля\\nОбращение в службу внутреннего контроля — это обратная линия, с помощью которой мы напрямую от партнёров и клиентов получаем информацию о том, насколько наша деятельность удовлетворяет вашим требованиям и ожиданиям.\\nВысказать своё замечание или предложение Вы можете заполнив онлайн-форму, либо позвонив напрямую в службу внутреннего контроля по телефону +7(495) 225-34-44 доб. 1645 или 1734\\nИмя\\nE-mail\\nТекст сообщения\\nВведите результат вычисления\\nПринимаю условия\\nпользовательского соглашения\\nи\\nполитики в отношении обработки персональных данных\\nОтправить\\nСпасибо, что помогаете нам стать еще лучше!\\nВсе поля формы обязательны для заполнения\\nБанки, 20.05.2025\\nБанковский сектор по итогам I квартала 2025 года: холодная весна 25-го\\nПоделиться\\nVK\\nPDF\\nСодержание\\nРезюме\\nРадикальное охлаждение\\nВ ожидании оттепели: б
# ...

# %% [markdown]
# ### ContextualCompressionRetriever

# %%
spans_df.loc[spans_df["name"] == "ContextualCompressionRetriever"].iloc[1]["attributes.input.value"]
# Out:
# 'сравнение лидеров финансового сектора РФ 2025'

# %%
spans_df.loc[spans_df["name"] == "ContextualCompressionRetriever"].iloc[1]["attributes.retrieval.documents"]
# Out:
# '[{\'document.content\': \'ОСНОВНЫЕ НАПРАВЛЕНИЯ \\nРАЗВИТИЯ ФИНАНСОВОГО РЫНКА \\nРОССИЙСКОЙ ФЕДЕРАЦИИ \\nНА\\xa02025\\xa0ГОД И\\xa0ПЕРИОД \\n2026\\xa0И\\xa02027\\xa0ГОДОВ\\n \\nМосква\\n2024\', \'document.metadata\': {\'title\': \'\', \'source\': \'http://www.cbr.ru/Content/Document/File/165924/onrfr_2025_2027.pdf\'}}, {\'document.content\': \'трлн ₽\\n3 место\\n29%\\n1,3\\nтрлн ₽\\n3 место\\n47%\\n61,4\\nмлрд ₽\\n5 место\\n17%\\n297,6\\nмлрд\\n5 место\\n22,7\\nмлрд ₽\\n5 место\\n12%\\n607,2\\nмлрд ₽\\n8 место\\n15%\\n461,7\\nмлрд ₽\\n8 место\\n31%\\n31,9\\nмлрд ₽\\n9 место\\n21%\\n231,1\\nмлрд\\n6 место\\n27,2\\nмлрд ₽\\n6 место\\n-16%\\n542,6\\nмлрд ₽\\n10 место\\n10%\\n190,6\\nмлрд ₽\\n14 место\\n28%\\n38,5\\nмлрд ₽\\n8 место\\n51%\\n211,3\\nмлрд\\n7 место\\n6,5\\nмлрд ₽\\n7 место\\n191%\\n1,5\\nтрлн ₽\\n5 место\\n13%\\n612,6\\nмлрд ₽\\n6 место\\n9%\\n22,1\\nмлрд ₽\\n11 место\\n22%\\n196,3\\nмлрд\\n8 место\\n45,8\\nмлрд ₽\\n8 место\\n147%\\n549,3\\nмлрд ₽\\n9 место\\n17%\\n580,4\\
# ...

# %% [markdown]
# ### Unnamed

# %%
spans_df.loc[spans_df["name"] == "Unnamed"].iloc[0]["attributes.input.value"]
# Out:
# '{"human_feedback": null, "task": {"max_sections": 3, "publish_formats": {"markdown": true, "pdf": true, "docx": true}, "include_human_feedback": false, "follow_guidelines": false, "model": "gigachat:GigaChat-2-Max", "guidelines": [], "language": "russian", "verbose": true, "query": "Проведи исследование и мотивируй схожие черты и различия личностных черт и профессиональных качеств Шувалова Игоря Ивановича - руководителя ВЭБ и Грефа Германа Оскарвича - руководителя Сбера."}, "initial_research": "# Исследование личностных черт и профессиональных качеств руководителей ВЭБ и Сбербанка\\n\\n## Введение\\n\\nСовременная экономика предъявляет высокие требования к руководителям крупных финансовых учреждений, таких как Внешэкономбанк (ВЭБ) и Сбербанк России. Личности этих руководителей играют ключевую роль в формировании имиджа и эффективности данных организаций. Цель данного исследования состоит в том, чтобы выявить сходства и различия между двумя известными российскими государственными дея
# ...

# %%
spans_df.loc[spans_df["name"] == "Unnamed"].iloc[0]["attributes.output.value"]
# Out:
# 'accept'

# %% [markdown]
# ### researcher

# %%
spans_df.loc[spans_df["name"] == "researcher"].iloc[0]["attributes.input.value"]
# Out:
# '{"task": {"max_sections": 3, "publish_formats": {"markdown": true, "pdf": true, "docx": true}, "include_human_feedback": false, "follow_guidelines": false, "model": "gigachat:GigaChat-2-Max", "guidelines": [], "language": "russian", "verbose": true, "query": "Проведи исследование и мотивируй схожие черты и различия личностных черт и профессиональных качеств Шувалова Игоря Ивановича - руководителя ВЭБ и Грефа Германа Оскарвича - руководителя Сбера."}, "topic": "Профессиональные навыки и управленческие стили"}'

# %%
spans_df.loc[spans_df["name"] == "researcher"].iloc[0]["attributes.output.value"]
# Out:
# '{"draft": {"Профессиональные навыки и управленческие стили": "## Профессиональные навыки и управленческие стили\\n\\nПрофессиональные навыки и управленческий стиль являются ключевыми факторами успеха любого лидера. Рассмотрим подробнее профессиональные характеристики и подходы к управлению двух выдающихся российских лидеров: Игоря Ивановича Шувалова и Германа Оскаровича Грефа.\\n\\n### Образование и профессиональная подготовка\\n\\n#### Игорь Шувалов\\nИгорь Шувалов получил юридическое образование, которое позволило ему начать карьеру в юридической практике. Впоследствии он прошел через различные государственные структуры, включая Министерство государственного имущества и Правительство Российской Федерации. Это дало ему возможность приобрести глубокие знания в сфере экономики и государственного управления. Сегодня он возглавляет государственную корпорацию развития «ВЭБ.РФ», демонстрируя высокий уровень профессионализма и компетентности в управлении крупными проектами и инвестициями 
# ...

# %% [markdown]
# ### LangGraph

# %%
spans_df.loc[spans_df["name"] == "LangGraph"].iloc[0]["attributes.input.value"]
# Out:
# '{"task": {"max_sections": 3, "publish_formats": {"markdown": true, "pdf": true, "docx": true}, "include_human_feedback": false, "follow_guidelines": false, "model": "gigachat:GigaChat-2-Max", "guidelines": [], "language": "russian", "verbose": true, "query": "Проведи исследование и мотивируй схожие черты и различия личностных черт и профессиональных качеств Шувалова Игоря Ивановича - руководителя ВЭБ и Грефа Германа Оскарвича - руководителя Сбера."}, "topic": "Профессиональные навыки и управленческие стили", "title": "# Исследование личностных черт и профессиональных качеств руководителей ВЭБ и Сбербанка", "headers": {}}'

# %%
spans_df.loc[spans_df["name"] == "LangGraph"].iloc[0]["attributes.output.value"]
# Out:
# '{"task": {"max_sections": 3, "publish_formats": {"markdown": true, "pdf": true, "docx": true}, "include_human_feedback": false, "follow_guidelines": false, "model": "gigachat:GigaChat-2-Max", "guidelines": [], "language": "russian", "verbose": true, "query": "Проведи исследование и мотивируй схожие черты и различия личностных черт и профессиональных качеств Шувалова Игоря Ивановича - руководителя ВЭБ и Грефа Германа Оскарвича - руководителя Сбера."}, "topic": "Профессиональные навыки и управленческие стили", "draft": {"Профессиональные навыки и управленческие стили": "## Профессиональные навыки и управленческие стили\\n\\nПрофессиональные навыки и управленческий стиль являются ключевыми факторами успеха любого лидера. Рассмотрим подробнее профессиональные характеристики и подходы к управлению двух выдающихся российских лидеров: Игоря Ивановича Шувалова и Германа Оскаровича Грефа.\\n\\n### Образование и профессиональная подготовка\\n\\n#### Игорь Шувалов\\nИгорь Шувалов получил юриди
# ...

# %% [markdown]
# ### reviewer

# %%
spans_df.loc[spans_df["name"] == "reviewer"].iloc[0]["attributes.input.value"]
# Out:
# '{"task": {"max_sections": 3, "publish_formats": {"markdown": true, "pdf": true, "docx": true}, "include_human_feedback": false, "follow_guidelines": false, "model": "gigachat:GigaChat-2-Max", "guidelines": [], "language": "russian", "verbose": true, "query": "Проведи исследование и мотивируй схожие черты и различия личностных черт и профессиональных качеств Шувалова Игоря Ивановича - руководителя ВЭБ и Грефа Германа Оскарвича - руководителя Сбера."}, "topic": "Профессиональные навыки и управленческие стили", "draft": {"Профессиональные навыки и управленческие стили": "## Профессиональные навыки и управленческие стили\\n\\nПрофессиональные навыки и управленческий стиль являются ключевыми факторами успеха любого лидера. Рассмотрим подробнее профессиональные характеристики и подходы к управлению двух выдающихся российских лидеров: Игоря Ивановича Шувалова и Германа Оскаровича Грефа.\\n\\n### Образование и профессиональная подготовка\\n\\n#### Игорь Шувалов\\nИгорь Шувалов получил юриди
# ...

# %%
spans_df.loc[spans_df["name"] == "reviewer"].iloc[0]["attributes.output.value"]
# Out:
# '{"review": null}'

# %% [markdown]
# ### planner

# %%
spans_df.loc[spans_df["name"] == "planner"].iloc[0]["attributes.input.value"]
# Out:
# '{"task": {"max_sections": 3, "publish_formats": {"markdown": true, "pdf": true, "docx": true}, "include_human_feedback": false, "follow_guidelines": false, "model": "gigachat:GigaChat-2-Max", "guidelines": [], "language": "russian", "verbose": true, "query": "Проведи исследование и мотивируй схожие черты и различия личностных черт и профессиональных качеств Шувалова Игоря Ивановича - руководителя ВЭБ и Грефа Германа Оскарвича - руководителя Сбера."}, "initial_research": "# Исследование личностных черт и профессиональных качеств руководителей ВЭБ и Сбербанка\\n\\n## Введение\\n\\nСовременная экономика предъявляет высокие требования к руководителям крупных финансовых учреждений, таких как Внешэкономбанк (ВЭБ) и Сбербанк России. Личности этих руководителей играют ключевую роль в формировании имиджа и эффективности данных организаций. Цель данного исследования состоит в том, чтобы выявить сходства и различия между двумя известными российскими государственными деятелями и банкамирами: Иг
# ...

# %%
spans_df.loc[spans_df["name"] == "planner"].iloc[0]["attributes.output.value"]
# Out:
# '{"title": "# Исследование личностных черт и профессиональных качеств руководителей ВЭБ и Сбербанка", "date": "16/07/2025", "sections": ["Образование и карьерный путь руководителей", "Профессиональные навыки и управленческие стили", "Личностные черты и влияние на общество"]}'

# %% [markdown]
# ### browser ?

# %%
spans_df.loc[spans_df["name"] == "browser"].iloc[0]["attributes.input.value"]
# Out:
# '{"task": {"max_sections": 3, "publish_formats": {"markdown": true, "pdf": true, "docx": true}, "include_human_feedback": false, "follow_guidelines": false, "model": "gigachat:GigaChat-2-Max", "guidelines": [], "language": "russian", "verbose": true, "query": "Проведи исследование и мотивируй схожие черты и различия личностных черт и профессиональных качеств Шувалова Игоря Ивановича - руководителя ВЭБ и Грефа Германа Оскарвича - руководителя Сбера."}}'

# %%
spans_df.loc[spans_df["name"] == "browser"].iloc[0]["attributes.output.value"]
# Out:
# '{"task": {"max_sections": 3, "publish_formats": {"markdown": true, "pdf": true, "docx": true}, "include_human_feedback": false, "follow_guidelines": false, "model": "gigachat:GigaChat-2-Max", "guidelines": [], "language": "russian", "verbose": true, "query": "Проведи исследование и мотивируй схожие черты и различия личностных черт и профессиональных качеств Шувалова Игоря Ивановича - руководителя ВЭБ и Грефа Германа Оскарвича - руководителя Сбера."}, "initial_research": "# Исследование личностных черт и профессиональных качеств руководителей ВЭБ и Сбербанка\\n\\n## Введение\\n\\nСовременная экономика предъявляет высокие требования к руководителям крупных финансовых учреждений, таких как Внешэкономбанк (ВЭБ) и Сбербанк России. Личности этих руководителей играют ключевую роль в формировании имиджа и эффективности данных организаций. Цель данного исследования состоит в том, чтобы выявить сходства и различия между двумя известными российскими государственными деятелями и банкамирами: Иг
# ...

# %% [markdown]
# ### human

# %%
spans_df.loc[spans_df["name"] == "human"].iloc[0]["attributes.input.value"]
# Out:
# '{"task": {"max_sections": 3, "publish_formats": {"markdown": true, "pdf": true, "docx": true}, "include_human_feedback": false, "follow_guidelines": false, "model": "gigachat:GigaChat-2-Max", "guidelines": [], "language": "russian", "verbose": true, "query": "Проведи исследование и мотивируй схожие черты и различия личностных черт и профессиональных качеств Шувалова Игоря Ивановича - руководителя ВЭБ и Грефа Германа Оскарвича - руководителя Сбера."}, "initial_research": "# Исследование личностных черт и профессиональных качеств руководителей ВЭБ и Сбербанка\\n\\n## Введение\\n\\nСовременная экономика предъявляет высокие требования к руководителям крупных финансовых учреждений, таких как Внешэкономбанк (ВЭБ) и Сбербанк России. Личности этих руководителей играют ключевую роль в формировании имиджа и эффективности данных организаций. Цель данного исследования состоит в том, чтобы выявить сходства и различия между двумя известными российскими государственными деятелями и банкамирами: Иг
# ...

# %%
spans_df.loc[spans_df["name"] == "human"].iloc[0]["attributes.output.value"]
# Out:
# '{"human_feedback": null}'

# %% [markdown]
# ### writer

# %%
spans_df.loc[spans_df["name"] == "writer"].iloc[0]["attributes.input.value"]
# Out:
# '{"task": {"max_sections": 3, "publish_formats": {"markdown": true, "pdf": true, "docx": true}, "include_human_feedback": false, "follow_guidelines": false, "model": "gigachat:GigaChat-2-Max", "guidelines": [], "language": "russian", "verbose": true, "query": "Проведи исследование и мотивируй схожие черты и различия личностных черт и профессиональных качеств Шувалова Игоря Ивановича - руководителя ВЭБ и Грефа Германа Оскарвича - руководителя Сбера."}, "initial_research": "# Исследование личностных черт и профессиональных качеств руководителей ВЭБ и Сбербанка\\n\\n## Введение\\n\\nСовременная экономика предъявляет высокие требования к руководителям крупных финансовых учреждений, таких как Внешэкономбанк (ВЭБ) и Сбербанк России. Личности этих руководителей играют ключевую роль в формировании имиджа и эффективности данных организаций. Цель данного исследования состоит в том, чтобы выявить сходства и различия между двумя известными российскими государственными деятелями и банкамирами: Иг
# ...

# %%
spans_df.loc[spans_df["name"] == "writer"].iloc[0]["attributes.output.value"]
# Out:
# '{"table_of_contents": "- Введение\\n- Образование и карьерный путь руководителей\\n- Ключевые достижения и вклад в экономику страны\\n- Профессиональные качества и лидерские навыки\\n- Благотворительная деятельность и социальные проекты\\n- Выводы и перспективы\\n- Профессиональные навыки и управленческие стили\\n- Личностные черты и влияние на общество", "introduction": "Исследование посвящено изучению личностных черт и профессиональных качеств руководителей двух крупнейших финансовых институтов России — ВЭБа и Сбербанка. В центре анализа находятся два известных деятеля: Герман Греф и Игорь Шувалов. Анализируются их биографические данные, образование, карьерный путь, профессиональные достижения, управленческие стили и вклад в развитие экономики страны.\\n\\n**Герман Греф**, президент и председатель правления Сбербанка России, обладает обширным опытом в банковской сфере и государственном управлении. После получения юридического образования в Омском государственном университете и зав
# ...

# %% [markdown]
# ### publisher

# %%
spans_df.loc[spans_df["name"] == "publisher"].iloc[0]["attributes.input.value"]
# Out:
# '{"task": {"max_sections": 3, "publish_formats": {"markdown": true, "pdf": true, "docx": true}, "include_human_feedback": false, "follow_guidelines": false, "model": "gigachat:GigaChat-2-Max", "guidelines": [], "language": "russian", "verbose": true, "query": "Проведи исследование и мотивируй схожие черты и различия личностных черт и профессиональных качеств Шувалова Игоря Ивановича - руководителя ВЭБ и Грефа Германа Оскарвича - руководителя Сбера."}, "initial_research": "# Исследование личностных черт и профессиональных качеств руководителей ВЭБ и Сбербанка\\n\\n## Введение\\n\\nСовременная экономика предъявляет высокие требования к руководителям крупных финансовых учреждений, таких как Внешэкономбанк (ВЭБ) и Сбербанк России. Личности этих руководителей играют ключевую роль в формировании имиджа и эффективности данных организаций. Цель данного исследования состоит в том, чтобы выявить сходства и различия между двумя известными российскими государственными деятелями и банкамирами: Иг
# ...

# %%
spans_df.loc[spans_df["name"] == "publisher"].iloc[0]["attributes.output.value"]
# Out:
# '# Исследование личностных черт и профессиональных качеств руководителей ВЭБ и Сбербанка\n\n## Введение\n\nНастоящее исследование направлено на изучение личностных черт и профессиональных качеств руководителей двух крупнейших финансовых институтов России — ВЭБа и Сбербанка. В фокусе внимания находятся два известных деятеля: Герман Греф и Игорь Шувалов. Рассматриваются их биографии, образование, карьерный путь, профессиональные достижения, управленческие стили и вклад в развитие экономики страны.\n\n**Герман Греф**, президент и председатель правления Сбербанка России, обладает богатым опытом в банковской сфере и государственном управлении. Получив юридическое образование в Омском государственном университете и завершив аспирантуру в Санкт-Петербурге под руководством известного политолога Анатолия Собчака, Греф начал свою карьеру в государственных структурах и банках. Его управленческая стратегия базируется на внедрении инноваций, цифровизации и модернизации, что привело к значительным
# ...

# %% [markdown]
# ### ArxivRetriever

# %%
spans_df.loc[spans_df["name"] == "ArxivRetriever"].iloc[1]["attributes.input.value"]
# Out:
# '2505.10468v1'

# %%
spans_df.loc[spans_df["name"] == "ArxivRetriever"].iloc[1]["attributes.retrieval.documents"]
# Out:
# "[{'document.content': 'This study critically distinguishes between AI Agents and Agentic AI,\\noffering a structured conceptual taxonomy, application mapping, and challenge\\nanalysis to clarify their divergent design philosophies and capabilities. We\\nbegin by outlining the search strategy and foundational definitions,\\ncharacterizing AI Agents as modular systems driven by Large Language Models\\n(LLMs) and Large Image Models (LIMs) for narrow, task-specific automation.\\nGenerative AI is positioned as a precursor, with AI Agents advancing through\\ntool integration, prompt engineering, and reasoning enhancements. In contrast,\\nAgentic AI systems represent a paradigmatic shift marked by multi-agent\\ncollaboration, dynamic task decomposition, persistent memory, and orchestrated\\nautonomy. Through a sequential evaluation of architectural evolution,\\noperational mechanisms, interaction styles, and autonomy levels, we present a\\ncomparative analysis across both paradigms. Applic
# ...

# %% [markdown]
# ## Labeling

# %%
import json

# %%
mask = (spans_df["span_kind"] == "RETRIEVER") & (
    spans_df["attributes.retrieval.documents"].isna() | 
    (spans_df["attributes.retrieval.documents"].apply(lambda x: x == "[]"))
)

no_search_results_df = spans_df.loc[mask]

# %%
import ast
import json
from pandas import isnull


def is_not_valid_output_message(x):
    if isnull(x) or not isinstance(x, str) or x.strip() == '[]':
        return True
    x = ast.literal_eval(x)
    try:
        if not isinstance(x, list) or len(x) == 0:
            return True
            
        last_msg = x[-1]
        
        if not isinstance(last_msg, dict) or 'message.content' not in last_msg:
            return True
            
        content = last_msg['message.content']
        
        if not isinstance(content, str):
            return True
            
        parsed = json.loads(content)
        
        required_fields = {'server', 'agent_role_prompt'}
        if not all(field in parsed for field in required_fields):
            return True
            
        if not isinstance(parsed['server'], str) or len(parsed['server']) == 0:
            return True
            
        return False
        
    except Exception:
        return True

mask = (spans_df["attributes.llm.input_messages"].notna() & 
    spans_df["attributes.llm.input_messages"].str.contains('You are a seasoned finance analyst AI assistant') &
    spans_df["attributes.llm.output_messages"].apply(is_not_valid_output_message)
    )

not_valid_json_df = spans_df.loc[mask]

# %%
errors_df = pd.concat([no_search_results_df, not_valid_json_df])

# %%
annotations = {row['context.span_id']: {"approved": False} for _, row in errors_df.iterrows()}

# %%
with open('../data/annotations/trace_annotations.json', 'w', encoding='utf-8') as f:
    json.dump(annotations, f, ensure_ascii=False, indent=2)
