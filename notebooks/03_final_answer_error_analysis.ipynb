# %%
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
# Out:
# True

# %%
from langchain_gigachat.chat_models import GigaChat
import pickle
from rich.markdown import Markdown
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers.string import StrOutputParser

# %%
llm = GigaChat(
    model="GigaChat-2-Max",
    verify_ssl_certs=False,
    profanity_check=False
)

llm.invoke("hello")
# Out:
# AIMessage(content='Привет!', additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 17, 'completion_tokens': 5, 'total_tokens': 22, 'precached_prompt_tokens': 3800}, 'model_name': 'GigaChat-2-Max:2.0.29.04', 'x_headers': {'x-request-id': '65245433-3d93-45e0-bc1c-86c960dad56b', 'x-session-id': '1c50efea-8c44-49d5-9cd6-987746312add', 'x-client-id': None}, 'finish_reason': 'stop'}, id='65245433-3d93-45e0-bc1c-86c960dad56b', usage_metadata={'output_tokens': 5, 'input_tokens': 17, 'total_tokens': 22, 'input_token_details': {'cache_read': 3800}})

# %%
with open('../data/annotations/annotations_2025-07-03.pkl', 'rb') as file_:
    annotations_ = pickle.load(file_)
annotations_[0]
# Out:
# {'index': 0,
#  'example': {'id': '09851372-b1d1-47f5-9451-3002038c1b3b',
#   'name': 'LangGraph',
#   'start_time': '2025-07-03 12:36:25.867023',
#   'run_type': 'chain',
#   'end_time': '2025-07-03 12:42:08.212201',
#   'extra': {'inputs_is_truthy': True,
#    'runtime': {'sdk': 'langsmith-py',
#     'sdk_version': '0.3.44',
#     'library': 'langsmith',
#     'platform': 'Windows-10-10.0.26100-SP0',
#     'runtime': 'python',
#     'py_implementation': 'CPython',
#     'runtime_version': '3.11.11',
#     'langchain_version': '0.3.25',
#     'langchain_core_version': '0.3.63'},
#    'metadata': {'revision_id': 'c4aea2a-dirty', 'ls_run_depth': 0}},
#   'error': None,
#   'serialized': None,
#   'events': [{'name': 'start', 'time': '2025-07-03T12:36:25.867023+00:00'},
#    {'name': 'end', 'time': '2025-07-03T12:42:08.212201+00:00'}],
#   'inputs': {'task': {'max_sections': 3,
#     'publish_formats': {'markdown': True, 'pdf': True, 'docx': True},
#     'include_human_feedback': False,
#     'follow_guidelines': False,
#     'model': 'gigachat:GigaChat-2-Max',
#     'guidelines': [],
#     'language': 'russian',
#     'verbose': True,
#     'query': 'КОНФЕРЕНЦИЯ POSITIVE HACK DAYS\nПЛЕНАРНОЕ СЕССИЯ «БЕСЧЕЛОВЕЧНЫЕ ТЕХНОЛОГИИ: ОСВОБОЖДЕНИЕ ОТ\nРУТИНЫ ИЛИ ПУТЬ К ЦИФРОВОМУ РАБСТВУ»\nПОВЕСТКА\nЦифровизация меняет наш мир с беспрецедентной скоростью.\nТехнологии, которые ещё вчера казались фантастикой, сегодня решают\nзадачи немыслимой сложности, оптимизируют процессы и кратно\nповышают производительность. Но за этим прогрессом скрывается\nсерьезная дилемма: внедрение новых технологий, искусственного\nинтеллекта и автоматизация трансформируют рынок труда, лишая людей\nпривычных профессий; стремительное внедрение цифровых\nинструментов сопровождаются ростом киберугроз, защита от которых\nтребует переосмысления практически всех сфер жизни – от моделей\nсоциального взаимодействия до системы образования, государственного\nуправления и личной ответственности в цифровой среде.\nПока одни опасаются «восстания машин», другие видят в автоматизации\nвозможность освободить человечество от рутины и направить его\nпотенциал на творчество и решение действительно значимых задач. В\nэтих условиях общество стоит перед сложным выбором: как обуздать\nразвитие технологий, которое сегодня рискует привести к\nэкзистенциальному кризису человечества, но при этом не задушить\nинновации?\nВОПРОСЫ К ОБСУЖДЕНИЮ\n1. Должны ли мы вообще бояться «восстания машин», или это мифы\nиз мира научной фантастики?\n2. Как минимизировать социальные издержки технологического\nпрогресса?\n3. Где проходит граница между технологическим развитием и\nограничениями, необходимыми ради безопасности?\n4. Какие профессии находятся под угрозой, а какие появятся\nблагодаря цифровой трансформации?\n5. Кто должен инвестировать в переподготовку сотрудников: бизнес,\nгосударство или люди сами должны приспосабливаться?\n6. Социальный контракт XXI века: какие взаимные обязательства\nпоявляются у бизнеса, государства и общества в эпоху ИИ?\n7. Как сделать так, чтобы технологии работали на благо всех?'}},
#   'outputs': {'task': {'max_sections': 3,
#     'publish_formats': {'markdown': True, 'pdf': True, 'docx': True},
#     'include_human_feedback': False,
#     'follow_guidelines': False,
#     'model': 'gigachat:GigaChat-2-Max',
#     'guidelines': [],
#     'language': 'russian',
#     'verbose': True,
#     'query': 'КОНФЕРЕНЦИЯ POSITIVE HACK DAYS\nПЛЕНАРНОЕ СЕССИЯ «БЕСЧЕЛОВЕЧНЫЕ ТЕХНОЛОГИИ: ОСВОБОЖДЕНИЕ ОТ\nРУТИНЫ ИЛИ ПУТЬ К ЦИФРОВОМУ РАБСТВУ»\nПОВЕСТКА\nЦифровизация меняет наш мир с беспрецедентной скоростью.\nТехнологии, которые ещё вчера казались фантастикой, сегодня решают\nзадачи немыслимой сложности, оптимизируют процессы и кратно\nповышают производительность. Но за этим прогрессом скрывается\nсерьезная дилемма: внедрение новых технологий, искусственного\nинтеллекта и автоматизация трансформируют рынок труда, лишая людей\nпривычных профессий; стремительное внедрение цифровых\nинструментов сопровождаются ростом киберугроз, защита от которых\nтребует переосмысления практически всех сфер жизни – от моделей\nсоциального взаимодействия до системы образования, государственного\nуправления и личной ответственности в цифровой среде.\nПока одни опасаются «восстания машин», другие видят в автоматизации\nвозможность освободить человечество от рутины и направить его\nпотенциал на творчество и решение действительно значимых задач. В\nэтих условиях общество стоит перед сложным выбором: как обуздать\nразвитие технологий, которое сегодня рискует привести к\nэкзистенциальному кризису человечества, но при этом не задушить\nинновации?\nВОПРОСЫ К ОБСУЖДЕНИЮ\n1. Должны ли мы вообще бояться «восстания машин», или это мифы\nиз мира научной фантастики?\n2. Как минимизировать социальные издержки технологического\nпрогресса?\n3. Где проходит граница между технологическим развитием и\nограничениями, необходимыми ради безопасности?\n4. Какие профессии находятся под угрозой, а какие появятся\nблагодаря цифровой трансформации?\n5. Кто должен инвестировать в переподготовку сотрудников: бизнес,\nгосударство или люди сами должны приспосабливаться?\n6. Социальный контракт XXI века: какие взаимные обязательства\nпоявляются у бизнеса, государства и общества в эпоху ИИ?\n7. Как сделать так, чтобы технологии работали на благо всех?'},
#    'initial_research': '## Конференция Positive Hack Days  \n### Пленарная сессия «Бесчеловечные технологии: Освобождение от рутины или путь к цифровому рабству?»  \n#### Повестка  \nЦифровизация изменяет наш мир с беспрецедентной скоростью. Технологии, которые еще недавно казались фантастикой, сегодня решают задачи невероятной сложности, оптимизируя процессы и многократно повышая производительность. Однако за этим прогрессом кроется серьезная дилемма: внедрение новых технологий, искусственного интеллекта и автоматизация преобразуют рынок труда, лишая людей привычных профессий; быстрое распространение цифровых инструментов сопровождается ростом киберугроз, защита от которых требует пересмотра практически всех аспектов жизни — от моделей социального взаимодействия до системы образования, государственного управления и личной ответственности в цифровой среде.  \n\nПока одни боятся «восстания машин», другие видят в автоматизации возможность освободить человечество от рутинных обязанностей и направить его потенциал на творчество и решение действительно важных задач. В этих условиях общество сталкивается со сложной задачей выбора: как контролировать развитие технологий, которое сейчас рискует привести к экзистенциальному кризису человечества, но при этом не подавить инновации?  \n\n### Вопросы к обсуждению  \n1. **Следует ли нам вообще опасаться «восстания машин», или это просто мифы из научной фантастики?**  \n   Современные исследования показывают, что опасения относительно восстания машин являются скорее плодом воображения писателей-фантастов, нежели реальной угрозой. Тем не менее, важно учитывать потенциальные риски, связанные с неконтролируемым распространением технологий искусственного интеллекта. По мнению многих экспертов, необходимо создавать механизмы регулирования и контроля над технологиями, чтобы избежать негативных последствий их применения ([in-text citation](https://phdays.com/ru/press-center/news/page/3)).  \n   \n2. **Как минимизировать социальные издержки технологического прогресса?**  \n   Одним из ключевых способов минимизации социальных издержек является активное вовлечение государственных структур и частного сектора в процесс подготовки кадров и адаптации работников к изменениям на рынке труда. Государственные инициативы, такие как программы профессиональной переподготовки и повышения квалификации, играют важную роль в решении этой задачи. Компании также несут ответственность за адаптацию своих сотрудников к новым условиям работы, внедряя корпоративные образовательные программы и поддерживая инициативу непрерывного профессионального роста ([in-text citation](https://phdays.com/ru/press-center/news/page/3)).  \n   \n3. **Где проходит граница между технологическим развитием и ограничениями, необходимыми ради безопасности?**  \n   Граница между технологическим развитием и необходимостью обеспечения безопасности определяется балансом интересов различных сторон. Важно создать систему регулирования, которая позволит эффективно управлять рисками без ограничения возможностей для инноваций. Это предполагает разработку стандартов и норм, обеспечивающих защиту данных и предотвращение злоупотреблений технологиями. Примерами таких инициатив могут служить международные соглашения и национальные законы, регулирующие использование искусственного интеллекта и роботизированных систем ([in-text citation](https://phdays.com/ru/press-center/news/page/3)).  \n   \n4. **Какие профессии находятся под угрозой исчезновения, а какие возникнут благодаря цифровой трансформации?**  \n   Согласно прогнозам аналитических агентств, ряд традиционных профессий, связанных с выполнением повторяющихся операций, находится под угрозой исчезновения вследствие автоматизации процессов. Вместе с тем появляются новые специальности, требующие навыков работы с данными, искусственным интеллектом и другими современными технологиями. Специалисты по анализу больших данных, разработчикам программного обеспечения и специалистам по кибербезопасности входят в числ ...
#    'sections': ['Риски и Возможности Искусственного Интеллекта',
#     'Адаптация Работников и Профессиональное Развитие',
#     'Регулирование Технологий и Защита Цифровых Пространств'],
#    'research_data': [{'Риски и Возможности Искусственного Интеллекта': '## Риски и Возможности Искусственного Интеллекта\n\n### Трансформация рынка труда и социальная адаптация\n\nШирокомасштабное внедрение искусственного интеллекта (ИИ) существенно изменяет структуру рынка труда, создавая как новые рабочие места, так и приводя к исчезновению традиционных профессий. Согласно исследованию Всемирного экономического форума, около **85 миллионов рабочих мест** будут утрачены к 2025 году вследствие технологических изменений ([ВЭФ спрогнозировал потерю 85 млн рабочих мест к 2025 г. из-за новых технологий](https://www.interfax.ru/world/732397)). Одновременно появляются новые профессии, связанные с разработкой, обслуживанием и управлением системами ИИ. Этот процесс сопровождается значительным спросом на высококвалифицированные кадры, способные работать с новыми технологиями.\n\nОднако массовая автоматизация процессов ставит перед обществом ряд серьезных вызовов. Во-первых, возникает проблема **структурной безработицы**, когда работники теряют свои позиции из-за замены их функций автоматизированными системами. Во-вторых, наблюдается тенденция к **поляризации рынка труда**: высокооплачиваемые специалисты получают дополнительные карьерные возможности, тогда как низкоквалифицированные сотрудники оказываются вытесненными с рынка труда. Наконец, многие страны испытывают дефицит квалифицированных специалистов в области информационных технологий и искусственного интеллекта, что усугубляет проблему нехватки рабочей силы в этих отраслях.\n\n### Безопасность данных и конфиденциальность\n\nОдним из главных рисков, связанных с широким внедрением ИИ, является угроза нарушения **безопасности личных данных**. Современные системы искусственного интеллекта собирают огромное количество информации о пользователях, которая затем обрабатывается и анализируется для оптимизации сервисов и предоставления персонализированного опыта. Однако сбор и обработка таких данных сопряжены с риском утечек, взлома и неправомерного использования информации. Особенно уязвимы персональные медицинские записи, банковские транзакции и другая чувствительная информация.\n\nКроме того, широкое распространение технологий распознавания лиц и голосового анализа повышает вероятность нарушений прав граждан на частную жизнь. Многие эксперты подчеркивают необходимость строгого регулирования сбора и хранения данных, обеспечения высокого уровня информационной безопасности и соблюдения международных стандартов защиты информации. Так, например, Европейская комиссия разработала руководство по использованию ИИ, направленное на защиту интересов граждан и ограничение возможных злоупотреблений ([European Union developed guidelines for ethical AI usage](https://ec.europa.eu/digital-single-market/en/news/commission-presented-artificial-intelligence-white-paper-and-european-data-strategy)).\n\n### Проблемы этики и доверия\n\nЭтические аспекты играют важную роль в обсуждении возможностей и рисков искусственного интеллекта. Одним из центральных вопросов является доверие к алгоритмам и принятие решений, принятых системой без участия человека. Автоматизированные системы часто принимают решения, основываясь на большом объеме данных, но эти решения могут оказаться несправедливыми или дискриминационными. Примеры включают случаи расовой или гендерной предвзятости в системах подбора персонала или выдачи кредитов.\n\nЕще одна важная проблема связана с ответственностью за действия ИИ-систем. Когда автономные машины совершают ошибки или наносят вред людям, кто несет юридическую ответственность: производитель программного обеспечения, владелец устройства или сама система? Ответ на этот вопрос пока остается открытым, поскольку законодательство многих стран не успевает адаптироваться к быстрым темпам технического прогресса.\n\n### Экологические последствия\n\nИспользование искусственного интеллекта также влечет за собой значительные экологические последствия. Мощные вычислительные ресурсы, необходимые для трениров ...
#     {'Адаптация Работников и Профессиональное Развитие': '## Адаптация Работников и Профессиональное Развитие  \n\n### Необходимость Постоянного Обучения и Переобучения  \nСовременный рынок труда стремительно меняется под воздействием цифровой трансформации и автоматизации. Многие привычные профессии постепенно уходят в прошлое, уступая место новым специальностям, связанным с технологиями искусственного интеллекта, робототехникой и другими современными направлениями. Например, согласно исследованию Bank of America Merrill Lynch, к 2025 году роботы и искусственный интеллект будут выполнять около 45% производственных задач, тогда как сейчас эта цифра составляет всего 10% ([Bank of America Merrill Lynch](https://cyberleninka.ru/article/n/podgotovka-kvalifitsirovannyh-professionalnyh-kadrov-v-usloviyah-razvitiya-sovremennyh-tehnologiy)).  \n\nЭто ставит перед обществом серьезный вызов: необходимо обеспечить подготовку и адаптацию работников к новой реальности. Без постоянного обновления своих компетенций сотрудники рискуют остаться вне рынка труда. Специалисты подчеркивают важность концепции "long-life education", предполагающей постоянное обучение и профессиональную переподготовку на протяжении всей трудовой карьеры.  \n\n### Кадровые Проблемы и Их Решение  \nОдной из главных проблем современной экономики является недостаток квалифицированных кадров в таких перспективных направлениях, как информационные технологии и кибербезопасность. Эксперты отмечают, что только в 2024 году в России ощущался дефицит порядка 100 тыс. специалистов в этих областях ([Минцифра РФ](https://imho.press/positive-hack-days-bolshe-chem-it-forum-budushhee-cifrovoj-bezopasnosti)).  \n\nДля решения данной проблемы необходимы активные меры со стороны государства, бизнеса и самих граждан. Государственные инициативы, такие как поддержка образовательных программ и стимулирование инвестиций в обучение, играют значительную роль. Бизнес-сообществу следует активно участвовать в формировании образовательных стандартов и финансировании курсов переподготовки. Наконец, каждому человеку нужно осознать личную ответственность за свое профессиональное развитие и быть готовым осваивать новые навыки.  \n\n### Инвестиции в Переподготовку Сотрудников  \nОдним из центральных вопросов конференции Positive Hack Days является обсуждение того, кто должен нести расходы на переподготовку сотрудников. Существует несколько подходов к решению этой проблемы:  \n\n- **Бизнес**: Компании заинтересованы в повышении квалификации своего персонала, поскольку это напрямую влияет на конкурентоспособность и прибыльность. Некоторые крупные корпорации уже внедряют внутренние программы обучения и стажировок.  \n- **Государство**: Правительство может поддерживать инициативу путем предоставления грантов, налоговых льгот и субсидий на обучение. Кроме того, государственные учреждения могут создавать специализированные центры переподготовки кадров.  \n- **Самостоятельная инициатива**: Люди должны брать на себя ответственность за собственное профессиональное развитие, регулярно обновляя свои навыки и умения.  \n\nОптимальное решение заключается в сочетании усилий всех трех сторон. Совместные усилия позволят создать эффективную систему подготовки и переподготовки кадров, способствующую успешной адаптации работников к изменениям на рынке труда.  \n\n### Новые Возможности и Угрозы Автоматизации  \nАвтоматизация и внедрение искусственного интеллекта открывают множество возможностей для повышения эффективности и продуктивности предприятий. Тем не менее, эти изменения несут определенные риски. Во-первых, существует опасность потери рабочих мест людьми, чьи функции могут быть заменены машинами. Во-вторых, возникают вопросы этического характера, связанные с применением алгоритмов принятия решений и обработкой персональных данных.  \n\nЧтобы минимизировать негативные последствия, необходимо развивать механизмы контроля над новыми технологиями и обеспечивать прозрачность их использования. Важно также формировать нов ...
#     {'Регулирование Технологий и Защита Цифровых Пространств': '## Регулирование Технологий и Защита Цифровых Пространств  \n\n### Бесчеловечные технологии: Освобождение от рутины или путь к цифровому рабству?\n\n#### Вопросы к обсуждению:\n1. **Страх перед восстанием машин**  \n   Современные технологии развиваются стремительно, и искусственный интеллект становится неотъемлемой частью нашей повседневной жизни. Однако опасения по поводу возможного восстания машин остаются предметом дискуссий. Эксперты подчеркивают, что страх перед технологиями часто преувеличен и основан на научных фантазиях, а не реальных угрозах ([in-text citation](https://ptsecurity.com/ru-ru/about/news/kiberfestival-positive-hack-days-projdet-22-24-maya-2025-goda)). Важно учитывать, что большинство технологических инноваций создаются людьми и контролируются ими же. Тем не менее, существует реальная угроза злоупотребления технологиями, например, использование систем распознавания лиц для слежки или манипуляции общественным мнением через алгоритмы соцсетей. Поэтому регулирование должно сосредоточиться на предотвращении подобных рисков без ограничения прогресса.\n\n2. **Минимизация социальных издержек технологического прогресса**  \n   Автоматизация процессов приводит к исчезновению традиционных профессий, что вызывает беспокойство среди населения. Для минимизации негативных последствий необходима продуманная стратегия перехода к новому типу занятости. Одним из возможных подходов является активное участие государства в программах переквалификации и переподготовки кадров. Бизнес-сообщество также играет важную роль, предоставляя сотрудникам возможности для освоения новых навыков и адаптируясь к изменяющимся условиям рынка труда. Примером успешного подхода служит инициатива Positive Technologies, которая проводит регулярные тренинги и семинары для своих сотрудников, обеспечивая их современными знаниями и навыками ([in-text citation](https://ptsecurity.com/ru-ru/about/news/kiberfestival-positive-hack-days-projdet-22-24-maya-2025-goda)).\n\n3. **Баланс между технологическим развитием и безопасностью**  \n   Граница между необходимостью внедрения инновационных технологий и обеспечением безопасности должна устанавливаться таким образом, чтобы минимизировать угрозы и сохранить свободу действий. Важнейшую роль здесь играют международные стандарты и нормативные акты, регулирующие применение технологий. Например, законодательство ЕС GDPR устанавливает строгие требования к обработке персональных данных, что помогает защитить права граждан в цифровую эпоху. Аналогичные меры принимаются и в других странах, включая Россию, где активно развивается правовая база регулирования использования больших данных и искусственного интеллекта.\n\n4. **Изменение структуры профессий**  \n   Некоторые традиционные профессии постепенно уходят в прошлое, уступая место новым специальностям, связанным с информационными технологиями и анализом данных. Согласно исследованиям, наибольшему риску подвергаются рабочие специальности, связанные с физическим трудом, тогда как специалисты в области программирования, аналитики данных и кибербезопасности пользуются высоким спросом. Компании, такие как Positive Technologies, активно развивают направления, связанные с защитой информации и разработкой программного обеспечения, создавая новые рабочие места и привлекая молодых специалистов ([in-text citation](https://ptsecurity.com/ru-ru/about/news/kiberfestival-positive-hack-days-projdet-22-24-maya-2025-goda)).\n\n5. **Ответственность за переподготовку сотрудников**  \n   Возникает важный вопрос: кто должен нести ответственность за переподготовку сотрудников в условиях быстро меняющегося рынка труда? Ответ лежит в плоскости совместного участия государства, бизнеса и самих работников. Государственные инициативы, такие как гранты и образовательные программы, помогают стимулировать процесс переквалификации. Корпорации, заинтересованные в сохранении высококвалифицированных кадров, создают внутренние учебные центр ...
#    'human_feedback': None,
#    'title': 'Технологический Прогресс и Социальные Вызовы',
#    'headers': {'title': 'Технологический Прогресс и Социальные Вызовы',
#     'date': 'Дата',
#     'introduction': 'Введение',
#     'table_of_contents': 'Содержание',
#     'conclusion': 'Заключение',
#     'references': 'Источники'},
#    'date': '03/07/2025',
#    'table_of_contents': '- Введение\n- Технологический прогресс и социальные вызовы\n  - Трансформация рынка труда и социальная адаптация\n  - Безопасность данных и конфиденциальность\n  - Проблемы этики и доверия\n  - Экологические последствия\n  - Экономические последствия\n- Адаптация работников и профессиональное развитие\n- Регулирование технологий и защита цифровых пространств\n- Заключение',
#    'introduction': '# Введение ([Технологический прогресс и социальные вызовы](#технологический-прогресс-и-социальные-вызовы))\n\nТехнологический прогресс оказывает глубокое влияние на различные сферы общественной жизни, особенно на трудовые отношения и цифровые пространства. Внедрение искусственного интеллекта (ИИ), автоматизации и цифровых технологий меняет структуру рынка труда, создает новые профессиональные возможности, одновременно порождая серьезные социальные вызовы.\n\n## Основные направления исследований\n\nИсследование рассматривает следующие ключевые аспекты влияния технологического прогресса на общество:\n\n- **Трансформация рынка труда и социальная адаптация**: Широкое распространение ИИ ведет к изменению структуры занятости, появлению новых профессий и сокращению старых. Это требует от работников постоянной профессиональной адаптации и непрерывного образования.\n\n- **Безопасность данных и конфиденциальность**: Распространение ИИ связано с увеличением объема собираемых данных и ростом риска их несанкционированного доступа и злоупотреблений.\n\n- **Проблемы этики и доверия**: Алгоритмы ИИ могут принимать несправедливые или дискриминационные решения, что вызывает вопросы об ответственности и доверии к технологиям.\n\n- **Экологические последствия**: Использование мощных вычислительных ресурсов для обучения ИИ-моделей приводит к значительному энергопотреблению и негативному воздействию на окружающую среду.\n\n- **Экономические последствия**: Автоматизация снижает затраты компаний, однако массовые увольнения вызывают нагрузку на государственные бюджеты и требуют продуманных стратегий социальной поддержки.\n\nТаким образом, технологический прогресс представляет собой сложный комплекс взаимосвязанных факторов, влияющих на различные аспекты жизни общества.\n\n([ВЭФ спрогнозировал потерю 85 млн рабочих мест к 2025 г. из-за новых технологий](https://www.interfax.ru/world/732397)',
#    'conclusion': '# Заключение\n\nТехнологический прогресс, основанный на искусственном интеллекте и автоматизации, значительно трансформирует общественные отношения и экономические процессы. Он открывает новые перспективы для роста производительности и создания высококачественных услуг, однако одновременно порождает серьезные социальные и этические вызовы.\n\n## Основные выводы\n\n1. **Необходимость профессиональной адаптации**: Быстрое изменение структуры рынка труда требует от работников постоянного профессионального развития и переобучения.\n\n2. **Защита конфиденциальности и безопасности данных**: Строгие законодательные и технические меры необходимы для предотвращения злоупотреблений личными данными и обеспечения информационной безопасности.\n\n3. **Формирование этически ответственного подхода**: Общество должно разработать механизмы контроля и прозрачности применения ИИ-технологий, чтобы избежать несправедливости и дискриминации.\n\n4. **Экологически устойчивое развитие**: Необходимо искать способы уменьшения негативного воздействия технологий на окружающую среду, используя более энергоэффективные подходы.\n\n5. **Глобальные экономические последствия**: Государства и компании должны разрабатывать стратегии социальной поддержки и содействия малому бизнесу, чтобы смягчить негативные экономические эффекты автоматизации.\n\nТаким образом, успешное управление технологическим прогрессом требует комплексного подхода, включающего государственное регулирование, корпоративную ответственность и индивидуальную инициативу.\n\n([European Union developed guidelines for ethical AI usage](https://ec.europa.eu/digital-single-market/en/news/commission-presented-artificial-intelligence-white-paper-and-european-data-strategy)',
#    'sources': ['- Всемирный экономический форум. (2025). *Потеря 85 млн рабочих мест к 2025 году из-за новых технологий*. [ВЭФ спрогнозировал потерю 85 млн рабочих мест к 2025 г. из-за новых технологий](https://www.interfax.ru/world/732397)',
#     '- Банк Америки Меррилл Линч. (2025). *Подготовка квалифицированных профессиональных кадров в условиях развития современных технологий*. [Bank of America Merrill Lynch](https://cyberleninka.ru/article/n/podgotovka-kvalifitsirovannyh-professionalnyh-kadrov-v-usloviyah-razvitiya-sovremennyh-tehnologiy)',
#     '- Минцифра РФ. (2024). *Дефицит специалистов в области информационных технологий и кибербезопасности в России*. [Минцифра РФ](https://imho.press/positive-hack-days-bolshe-chem-it-forum-budushhee-cifrovoj-bezopasnosti)',
#     '- European Union. (2025). *Комиссия представила белую книгу по искусственному интеллекту и европейскую стратегию данных*. [European Union developed guidelines for ethical AI usage](https://ec.europa.eu/digital-single-market/en/news/commission-presented-artificial-intelligence-white-paper-and-european-data-strategy)'],
#    'report': '# Технологический Прогресс и Социальные Вызовы\n#### Дата: 03/07/2025\n\n## Введение\n# Введение ([Технологический прогресс и социальные вызовы](#технологический-прогресс-и-социальные-вызовы))\n\nТехнологический прогресс оказывает глубокое влияние на различные сферы общественной жизни, особенно на трудовые отношения и цифровые пространства. Внедрение искусственного интеллекта (ИИ), автоматизации и цифровых технологий меняет структуру рынка труда, создает новые профессиональные возможности, одновременно порождая серьезные социальные вызовы.\n\n## Основные направления исследований\n\nИсследование рассматривает следующие ключевые аспекты влияния технологического прогресса на общество:\n\n- **Трансформация рынка труда и социальная адаптация**: Широкое распространение ИИ ведет к изменению структуры занятости, появлению новых профессий и сокращению старых. Это требует от работников постоянной профессиональной адаптации и непрерывного образования.\n\n- **Безопасность данных и конфиденциальность**: Распространение ИИ связано с увеличением объема собираемых данных и ростом риска их несанкционированного доступа и злоупотреблений.\n\n- **Проблемы этики и доверия**: Алгоритмы ИИ могут принимать несправедливые или дискриминационные решения, что вызывает вопросы об ответственности и доверии к технологиям.\n\n- **Экологические последствия**: Использование мощных вычислительных ресурсов для обучения ИИ-моделей приводит к значительному энергопотреблению и негативному воздействию на окружающую среду.\n\n- **Экономические последствия**: Автоматизация снижает затраты компаний, однако массовые увольнения вызывают нагрузку на государственные бюджеты и требуют продуманных стратегий социальной поддержки.\n\nТаким образом, технологический прогресс представляет собой сложный комплекс взаимосвязанных факторов, влияющих на различные аспекты жизни общества.\n\n([ВЭФ спрогнозировал потерю 85 млн рабочих мест к 2025 г. из-за новых технологий](https://www.interfax.ru/world/732397)\n\n## Содержание\n- Введение\n- Технологический прогресс и социальные вызовы\n  - Трансформация рынка труда и социальная адаптация\n  - Безопасность данных и конфиденциальность\n  - Проблемы этики и доверия\n  - Экологические последствия\n  - Экономические последствия\n- Адаптация работников и профессиональное развитие\n- Регулирование технологий и защита цифровых пространств\n- Заключение\n\n## Риски и Возможности Искусственного Интеллекта\n\n### Трансформация рынка труда и социальная адаптация\n\nШирокомасштабное внедрение искусственного интеллекта (ИИ) существенно изменяет структуру рынка труда, создавая как новые рабочие места, так и приводя к исчезновению традиционных профессий. Согласно исследованию Всемирного экономического форума, около **85 миллионов рабочих мест** будут утрачены к 2025 году вследствие технологических изменений ([ВЭФ спрогнозировал потерю 85 млн рабочих мест к 2025 г. из-за новых технологий](https://www.interfax.ru/world/732397)). Одновременно появляются новые профессии, связанные с разработкой, обслуживанием и управлением системами ИИ. Этот процесс сопровождается значительным спросом на высококвалифицированные кадры, способные работать с новыми технологиями.\n\nОднако массовая автоматизация процессов ставит перед обществом ряд серьезных вызовов. Во-первых, возникает проблема **структурной безработицы**, когда работники теряют свои позиции из-за замены их функций автоматизированными системами. Во-вторых, наблюдается тенденция к **поляризации рынка труда**: высокооплачиваемые специалисты получают дополнительные карьерные возможности, тогда как низкоквалифицированные сотрудники оказываются вытесненными с рынка труда. Наконец, многие страны испытывают дефицит квалифицированных специалистов в области информационных технологий и искусственного интеллекта, что усугубляет проблему нехватки рабочей силы в этих отраслях.\n\n### Безопасность данных и конфиденциальность\n\nОдним из главных рисков, связанных с широким внедрением ИИ, является угроза наруш ...
#   'reference_example_id': None,
#   'parent_run_id': None,
#   'tags': [],
#   'attachments': {},
#   'session_id': 'b3e08334-fa8a-4d5a-b8fa-27b15219d872',
#   'child_run_ids': None,
#   'child_runs': None,
#   'feedback_stats': None,
#   'app_path': '/o/9305778f-7a80-471e-8d3c-05f6703cd38c/projects/p/b3e08334-fa8a-4d5a-b8fa-27b15219d872/r/09851372-b1d1-47f5-9451-3002038c1b3b?trace_id=09851372-b1d1-47f5-9451-3002038c1b3b&start_time=2025-07-03T12:36:25.867023',
#   'manifest_id': None,
#   'status': 'success',
#   'prompt_tokens': 52722,
#   'completion_tokens': 10572,
#   'total_tokens': 63294,
#   'prompt_token_details': None,
#   'completion_token_details': None,
#   'first_token_time': '2025-07-03 12:36:56.814400',
#   'total_cost': None,
#   'prompt_cost': None,
#   'completion_cost': None,
#   'prompt_cost_details': None,
#   'completion_cost_details': None,
#   'parent_run_ids': [],
#   'trace_id': '09851372-b1d1-47f5-9451-3002038c1b3b',
#   'dotted_order': '20250703T123625867023Z09851372-b1d1-47f5-9451-3002038c1b3b',
#   'in_dataset': False,
#   '_html': '<p><strong>Вопрос: </strong>КОНФЕРЕНЦИЯ POSITIVE HACK DAYS\nПЛЕНАРНОЕ СЕССИЯ «БЕСЧЕЛОВЕЧНЫЕ ТЕХНОЛОГИИ: ОСВОБОЖДЕНИЕ ОТ\nРУТИНЫ ИЛИ ПУТЬ К ЦИФРОВОМУ РАБСТВУ»\nПОВЕСТКА\nЦифровизация меняет наш мир с беспрецедентной скоростью.\nТехнологии, которые ещё вчера казались фантастикой, сегодня решают\nзадачи немыслимой сложности, оптимизируют процессы и кратно\nповышают производительность. Но за этим прогрессом скрывается\nсерьезная дилемма: внедрение новых технологий, искусственного\nинтеллекта и автоматизация трансформируют рынок труда, лишая людей\nпривычных профессий; стремительное внедрение цифровых\nинструментов сопровождаются ростом киберугроз, защита от которых\nтребует переосмысления практически всех сфер жизни – от моделей\nсоциального взаимодействия до системы образования, государственного\nуправления и личной ответственности в цифровой среде.\nПока одни опасаются «восстания машин», другие видят в автоматизации\nвозможность освободить человечество от рутины и направить его\nпотенциал на творчество и решение действительно значимых задач. В\nэтих условиях общество стоит перед сложным выбором: как обуздать\nразвитие технологий, которое сегодня рискует привести к\nэкзистенциальному кризису человечества, но при этом не задушить\nинновации?\nВОПРОСЫ К ОБСУЖДЕНИЮ\n1. Должны ли мы вообще бояться «восстания машин», или это мифы\nиз мира научной фантастики?\n2. Как минимизировать социальные издержки технологического\nпрогресса?\n3. Где проходит граница между технологическим развитием и\nограничениями, необходимыми ради безопасности?\n4. Какие профессии находятся под угрозой, а какие появятся\nблагодаря цифровой трансформации?\n5. Кто должен инвестировать в переподготовку сотрудников: бизнес,\nгосударство или люди сами должны приспосабливаться?\n6. Социальный контракт XXI века: какие взаимные обязательства\nпоявляются у бизнеса, государства и общества в эпоху ИИ?\n7. Как сделать так, чтобы технологии работали на благо всех?</p>\n<p><strong>Отчет:</strong></p>\n<h1>Технологический Прогресс и Социальные Вызовы</h1>\n<h4>Дата: 03/07/2025</h4>\n<h2>Введение</h2>\n<h1>Введение (<a href="#технологический-прогресс-и-социальные-вызовы">Технологический прогресс и социальные вызовы</a>)</h1>\n<p>Технологический прогресс оказывает глубокое влияние на различные сферы общественной жизни, особенно на трудовые отношения и цифровые пространства. Внедрение искусственного интеллекта (ИИ), автоматизации и цифровых технологий меняет структуру рынка труда, создает новые профессиональные возможности, одновременно порождая серьезные социальные вызовы.</p>\n<h2>Основные направления исследований</h2>\n<p>Исследование рассматривает следующие ключевые аспекты влияния технологического прогресса на общество:</p>\n<ul>\n<li>\n<p><strong>Трансформация рынка труда и социальная адаптация</strong>: Широкое распространение ИИ ведет к изменению структуры занятости, появлению новых профессий и сокращению старых. Это требует от работников постоянной профессиональной адаптации и непрерывного образования.</p>\n</li>\n<li>\n<p><strong>Безопасность данных и конфиденциальность</strong>: Распространение ИИ связано с увеличением объема собираемых данных и ростом риска их несанкционированного доступа и злоупотреблений.</p>\n</li>\n<li>\n<p><strong>Проблемы этики и доверия</strong>: Алгоритмы ИИ могут принимать несправедливые или дискриминационные решения, что вызывает вопросы об ответственности и доверии к технологиям.</p>\n</li>\n<li>\n<p><strong>Экологические последствия</strong>: Использование мощных вычислительных ресурсов для обучения ИИ-моделей приводит к значительному энергопотреблению и негативному воздействию на окружающую среду.</p>\n</li>\n<li>\n<p><strong>Экономические последствия</strong>: Автоматизация снижает затраты компаний, однако массовые увольнения вызывают нагрузку на государственные бюджеты и требуют продуманных стратегий социальной поддержки.</p>\n</li>\n</ul>\n<p>Таким образом, технологический прогресс представляет собой сложный комплекс взаимо ...
#  '_label': 'yes',
#  '_notes': 'про экологические последствия - вода не по теме;\nЕсть заголовок в содержании, но его нет в тексте остальном;\nГрамматическая ошибка - новые рабочие места и приводя не однородные -  "Широкомасштабное внедрение искусственного интеллекта (ИИ) существенно изменяет структуру рынка труда, создавая как новые рабочие места, так и приводя к исчезновению традиционных профессий";\nПо ссылке нет контента, открывается страница, что нет такой страницы;\nМного комментариев по инструкции, что эти разделы соответствуют критериям и т.д.;\nНе ориентируется во времени публикаций и не понимает, какой год сейчас - "к 2025 году роботы и искусственный интеллект будут выполнять около 45% производственных задач, тогда как сейчас эта цифра составляет всего 10%";\nНесколько раз одни и те же мысли повторяет;\n"трудовая карьера" - плеоназм, возможно;\nin-text citation текст, а не название статьи допустим;\nВстречаются громкие заявления не подтвержденные источниками;\nДва раза название раздела заключение;\nГод у источников выдумывает;',
#  '_timestamp': '2025-08-04T07:12:10.888Z'}

# %%
errors = []
for annotation in annotations_:
    errors.extend(annotation['_notes'].split('\n'))
len(errors)
# Out:
# 64

# %% [markdown]
# ## Using LLM

# %%
errors_str = ' '.join(errors)

# %%
system = """Ты — опытный аналитик, который помогает классифицировать и анализировать ошибки на основе кратких описаний.  

**Задача:**  
1. Проанализируй предоставленные заметки об ошибках.  
2. Сгруппируй похожие ошибки, дав каждой группе четкое и понятное название (например, "Ошибка аутентификации", "Проблемы с загрузкой данных", "Некорректное отображение UI").  
3. Составь отчет в следующем формате:  
 
## [Название ошибки]
[Четкое её Описание]
## [Название ошибки]
[Четкое её Описание]
...  
"""

prompt = ChatPromptTemplate.from_messages([("system", system), ("user", "{user_input}")])

# %%
chain = prompt | llm | StrOutputParser()

# %%
Markdown(chain.invoke({"user_input": errors_str}))
# Out:
#                                            Проблемы с содержанием текста
#
# Отсутствует соответствие между оглавлением и фактическим текстом документа ("Есть заголовок в содержании, но его
# нет в тексте остальном").
#
#
#                                              Повторения и избыточность
#
# Несколько раз повторяются одинаковые мысли разными словами ("Много раз одну и ту же инфо пишет, просто другими
# словами").
#
#
#                                     Некорректное оформление ссылок и источников
#
# Ссылки ведут на несуществующие ресурсы или содержат неверную информацию ("По ссылке нет контента, открывается
# страница, что нет такой страницы", "Год у источников выдумывает", "ссылки на несуществующий ресурс", "где-то с
# сайтов взяли прямую рекламу конкретных компаний, что мб не ок").
#
#
#                                    Отсутствие подтверждений фактов и утверждений
#
# Утверждения не подкреплены достоверными источниками ("Встречаются громкие заявления не подтвержденные источниками",
# "факты, не подтвержденные источниками", "инфо вообще не подтвержденная источниками").
#
#
#                                       Стилистические и грамматические ошибки
#
# Имеется ряд стилистических ошибок и плеоназмов ("Грамматическая ошибка – 'создавая как новые рабочие места, так и
# приводя к исчезновению традиционных профессий'", "трудовая карьера – плеоназм").
#
#
#                                    Ошибки оформления структуры и форматирования
#
# Повторяется одно и то же название раздела ("слово заключение два раза написано"), присутствуют проблемы с
# оформлением markdown-разметки ("не везде маркдаун полностью корректен, из-за этого в отчёте встречаются **").
#
#
#                                       Некачественные и некорректные источники
#
# Используются некачественные и недостоверные сайты ("самие источники сомнительного качества", "sources example
# domain", "очень общие ссылки, на сайте много статей, непонятно, на какую именно ссылаются").
#
#
#                             Неправильное использование цитат и библиографического стиля
#
# Цитаты оформляются неправильно ("цитаты в тексте называют просто – in-text citation"), нарушены требования
# заданного формата оформления списка литературы ("источники в другом стиле представлены, не в заявленном").
#
#
#                                   Логически необоснованное объединение материалов
#
# Необоснованно объединены разнородные данные ("сомнительное объединение двух таблиц в одну – профессии старые и
# новые, но в одной строке просто две рандомные, не связанные между собой профессии").

# %% [markdown]
# ## Using Clusterization

# %%
from bertopic.backend import BaseEmbedder
from langchain_gigachat.embeddings import GigaChatEmbeddings

class CustomEmbedder(BaseEmbedder):
    def __init__(self, embedding_model):
        super().__init__()
        self.embedding_model = embedding_model

    def embed(self, documents, verbose=False):
        embeddings = self.embedding_model.embed_documents(documents)
        return embeddings 

# Create custom backend
emb_m = GigaChatEmbeddings(model="EmbeddingsGigaR", verify_ssl_certs=False)
custom_embedder = CustomEmbedder(embedding_model=emb_m)

# %%
from umap import UMAP

umap_model = UMAP(n_neighbors=3, n_components=3, min_dist=0.0, metric='cosine')

# %%
from hdbscan import HDBSCAN

hdbscan_model = HDBSCAN(min_cluster_size=2, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# %% [raw]
# from bertopic.representation import MaximalMarginalRelevance
#
# representation_model = MaximalMarginalRelevance(diversity=0.3)

# %%
from bertopic import BERTopic
import numpy as np

topic_model = BERTopic(embedding_model=custom_embedder, calculate_probabilities=True, verbose=True, hdbscan_model=hdbscan_model, umap_model=umap_model)
embeddings = custom_embedder.embed(errors)
embeddings = np.array(embeddings)

# %%
topics, probs = topic_model.fit_transform(errors, embeddings)
# Out:
# 2025-08-04 11:44:07,610 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-08-04 11:44:20,724 - BERTopic - Dimensionality - Completed ✓
# 2025-08-04 11:44:20,726 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-08-04 11:44:20,776 - BERTopic - Cluster - Completed ✓
# 2025-08-04 11:44:20,791 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-08-04 11:44:20,825 - BERTopic - Representation - Completed ✓

# %%
freq = topic_model.get_topic_info(); freq
# Out:
#     Topic  Count                                               Name  \
# 0       0     21                                              0____
# 1       1      6  1_источниками_вообще_подтвержденная_подтвержде...
# 2       2      6                            2_же_раз_повторяет_вода
# 3       3      5                        3_заключение_два_раза_слово
# 4       4      5                        4_нет_ссылки_domain_example
# 5       5      4                        5_text_in_citation_называют
# 6       6      4                          6_новые_приводя_места_как
# 7       7      4                             7_общие_на_очень_много
# 8       8      3                    8_заголовок_информацию_его_есть
# 9       9      3                    9_bigtranstour_2025_accessed_at
# 10     10      3                      10_источнике_говорит_отчет_та
#
#                                        Representation  \
# 0                                [, , , , , , , , , ]
# 1   [источниками, вообще, подтвержденная, подтверж...
# 2   [же, раз, повторяет, вода, инфу, ту, другими, ...
# 3   [заключение, два, раза, слово, написано, дважд...
# 4   [нет, ссылки, domain, example, конкретных, нес...
# 5   [text, in, citation, называют, цитаты, тексте,...
# 6   [новые, приводя, места, как, рабочие, професси...
# 7   [общие, на, очень, много, запятую, какую, комм...
# 8   [заголовок, информацию, его, есть, качества, и...
# 9   [bigtranstour, 2025, accessed, at, 03, availab...
# 10  [источнике, говорит, отчет, та, инфа, за, везд...
#
#                                   Representative_Docs
# 0                                              [, , ]
# 1   [Встречаются громкие заявления не подтвержденн...
# 2   [Несколько раз одни и те же мысли повторяет;, ...
# 3   [слово заключение два раза написано;, слово за...
# 4   [ссылки на несуществующий ресурс;, По ссылке н...
# 5   [цитаты в тексте называют просто - in-text cit...
# 6   [сомнительное объединение двух таблиц в одну -...
# 7   [просто  перечислил сразу кучу источников чере...
# 8   [сами источники сомнительного качества;, источ...
# 9   [Год у источников выдумывает;, источники в дру...
# 10  [не везде маркдаун полностью корректен, из-за ...

# %%
topic_model.get_topic(1)
# Out:
# [('источниками', np.float64(0.3496807322917733)),
#  ('вообще', np.float64(0.19739316420203232)),
#  ('подтвержденная', np.float64(0.19739316420203232)),
#  ('подтвержденные', np.float64(0.19739316420203232)),
#  ('не', np.float64(0.19540585010500372)),
#  ('инфа', np.float64(0.15342231389822994)),
#  ('громкие', np.float64(0.12159863877986764)),
#  ('заявления', np.float64(0.12159863877986764)),
#  ('подтвержденных', np.float64(0.12159863877986764)),
#  ('факты', np.float64(0.12159863877986764))]

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_hierarchy(top_n_topics=50)

# %%
topic_model.visualize_heatmap()
